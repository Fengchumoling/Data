# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
titanic_df = pd.read_csv('train.csv')
titanic_df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Q1 Who were the passengers on Titanic??
titanic_df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic_df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
#sns.factorplot('sex',data=titanic_df,kind="count")
# shows that there are more male passengers as compared to female passangers
sns.catplot(data= titanic_df,kind="count",x="Sex")

# %%
titanic_df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
# Distribution of males and females based on pclass and place of embarkment
titanic_df.groupby(['Pclass','Sex','Embarked']).size()
# Out:
# Pclass  Sex     Embarked
# 1       female  C            43
#                 Q             1
#                 S            48
#         male    C            42
#                 Q             1
#                 S            79
# 2       female  C             7
#                 Q             2
#                 S            67
#         male    C            10
#                 Q             1
#                 S            97
# 3       female  C            23
#                 Q            33
#                 S            88
#         male    C            43
#                 Q            39
#                 S           265
# dtype: int64

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(titanic_df.groupby(['Pclass','Sex']).size())
print()
sex_age_df = pd.crosstab(index=[titanic_df['Pclass']], columns=[titanic_df['Sex']])
sex_age_df
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# dtype: int64
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
#sns.factorplot('pclass',data=titanic_df,kind='count',hue='Sex')
sns.catplot(data= titanic_df,kind="count",hue="Sex",x="Pclass")

# %%
def male_female_child(passenger):
    age,sex = passenger
    
    if age < 16:
        return 'child'
    else:
        return sex

# %%
titanic_df['Person'] = titanic_df[['Age','Sex']].apply(male_female_child,axis = 1)

# %%
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male
# 5      0            330877   8.4583   NaN        Q    male
# 6      0             17463  51.8625   E46        S    male
# 7      1            349909  21.0750   NaN        S   child
# 8      2            347742  11.1333   NaN        S  female
# 9      0            237736  30.0708   NaN        C   child

# %%
titanic_df.groupby(['Pclass','Person']).size()
# Out:
# Pclass  Person
# 1       child       6
#         female     91
#         male      119
# 2       child      19
#         female     66
#         male       99
# 3       child      58
#         female    114
#         male      319
# dtype: int64

# %%
#sns.factorplot('pclass',data=titanic_df,kind='count',hue='person')
sns.catplot(data= titanic_df,kind="count",hue="Person",x="Pclass")

# %%
# Ages of people 
titanic_df['Age'].hist(bins = 70)
# Mean is around 30
# Out:
# <AxesSubplot: >

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['Person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: Person, dtype: int64

# %%
#fig = sns.facetGrid(titanic_df,hue='sex',aspect=4)
fig = sns.FacetGrid(titanic_df,hue='Sex',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()
# Out:
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
fig = sns.FacetGrid(titanic_df,hue='Person',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))
fig.add_legend()
# Out:
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Distribution of female ages
titanic_df[titanic_df['Sex'] == 'female']['Age'].hist(bins = 70)
# Out:
# <AxesSubplot: >

# %%
# Distribution of male ages
titanic_df[titanic_df['Sex'] == 'male']['Age'].hist(bins = 70)
# Out:
# <AxesSubplot: >

# %%
#How age is distributed w.r.t. to class
fig = sns.FacetGrid(titanic_df,hue='Pclass',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))
fig.add_legend()
# Out:
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Q2 What deck the passengers on and how does it relate to their class?
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male

# %%
# Percentage of Null Values in all columns =
p_null= (len(titanic_df) - titanic_df.count())*100.0/len(titanic_df)
p_null
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# Person          0.000000
# dtype: float64

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Person'],
#       dtype='object')

# %%
# Percentage of Null Values in cabin column =
p_null_cabin= (len(titanic_df['Cabin']) - titanic_df['Cabin'].count())*100.0/len(titanic_df['Cabin'])
p_null_cabin
# Out:
# 77.10437710437711

# %%
#sns.Factorplot('pclass', data=titanic_df, kind='count', hue='person', order=[1,2,3], 
  #             hue_order=['child','female','male'], aspect=2)
sns.catplot(data= titanic_df,kind="count",hue="Person",x="Pclass",order=[1,2,3],hue_order=['child','female','male'], aspect=2)

# %%
# Do the same as above, but split the passengers into either survived or not
#sns.factorplot('pclass', data=titanic_df, kind='count', hue='person', col='survived', order=[1,2,3], 
 #              hue_order=['child','female','male'], aspect=1.25, size=5)
sns.catplot(data= titanic_df,kind="count",hue="Person",x="Pclass",col="Survived",order=[1,2,3],hue_order=['child','female','male'], aspect=1.25)

# %% [markdown]
# # Where did the passengers come from i.e. Where did the passengers land into the ship from?

# %%
#sns.factorplot('embarked', data=titanic_df, kind='count', hue='pclass')
sns.catplot(data= titanic_df,kind="count",hue="Pclass",x="Embarked",col="Survived")

# %% [markdown]
# From the figure above, one may conclude that almost all of the passengers who boarded from Queenstown were in third class. On the other hand, many who boarded from Cherbourg were in first class. The biggest portion of passengers who boarded the ship came from Southampton, in which 353 passengers were in third class, 164 in second class and 127 passengers were in first class. In such cases, one may need to look at the economic situation at these different towns at that period of time to understand why most passengers who boarded from Queenstown were in third class for example.

# %%
titanic_df.groupby(['Embarked','Pclass']).size()
# Out:
# Embarked  Pclass
# C         1          85
#           2          17
#           3          66
# Q         1           2
#           2           3
#           3          72
# S         1         127
#           2         164
#           3         353
# dtype: int64

# %%
titanic_df.embarked.value_counts()
# Out:
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
embarked_vs_pclass = pd.crosstab(index = [titanic_df['Embarked']], columns=[titanic_df['Pclass']],margins=True)
embarked_vs_pclass
# Out:
# Pclass      1    2    3  All
# Embarked
# C          85   17   66  168
# Q           2    3   72   77
# S         127  164  353  644
# All       214  184  491  889

# %%
def alone_with_family(passenger):
    parch,sibsp = passenger
    if (parch == 0) & (sibsp == 0):
        return 'alone'
    else:
        return 'with_family'

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Person'],
#       dtype='object')

# %%
titanic_df['alone_or_with_family'] = titanic_df[['Parch','SibSp']].apply(alone_with_family,axis = 1)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person  \
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male
#
#   alone_or_with_family
# 0          with_family
# 1          with_family
# 2                alone
# 3          with_family
# 4                alone

# %%
titanic_df['alone_or_with_family'].value_counts()
# Out:
# alone          537
# with_family    354
# Name: alone_or_with_family, dtype: int64

# %%
#fg=sns.factorplot('alone_or_with_family', data=titanic_df, kind='count', hue='Pclass', col='Person')
sns.catplot(data= titanic_df,kind="count",hue="pclass",x="alone_or_with_family",col="survived")
# Out:
# C:\Users\LH\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
pd.crosstab(index = [titanic_df['alone_or_with_family'],titanic_df['Person']], columns=[titanic_df['Pclass']],margins=True)
# Out:
# Pclass                         1    2    3  All
# alone_or_with_family Person
# alone                child     0    0    6    6
#                      female   34   32   55  121
#                      male     75   72  263  410
# with_family          child     6   19   52   77
#                      female   57   34   59  150
#                      male     44   27   56  127
# All                          216  184  491  891

# %%
def titanic_preprocessing(train, test):
    train_df = pd.read_csv(train)
    test_df = pd.read_csv(test)
    combine = [train_df, test_df]

    train_df = train_df.drop(['Ticket', 'Cabin'], axis=1)
    test_df = test_df.drop(['Ticket', 'Cabin'], axis=1)
    combine = [train_df, test_df]

    for dataset in combine:
        dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

    pd.crosstab(train_df['Title'], train_df['Sex'])

    for dataset in combine:
        dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
        'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

        dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
        dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
        dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

    train_df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()

    title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
    for dataset in combine:
        dataset['Title'] = dataset['Title'].map(title_mapping)
        dataset['Title'] = dataset['Title'].fillna(0)

    train_df = train_df.drop(['Name', 'PassengerId'], axis=1)
    test_df = test_df.drop(['Name'], axis=1)
    combine = [train_df, test_df]

    for dataset in combine:
        dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

    guess_ages = np.zeros((2,3))
    guess_ages

    for dataset in combine:
        for i in range(0, 2):
            for j in range(0, 3):
                guess_df = dataset[(dataset['Sex'] == i) & \
                                      (dataset['Pclass'] == j+1)]['Age'].dropna()

                age_guess = guess_df.median()

                guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5

        for i in range(0, 2):
            for j in range(0, 3):
                dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),\
                        'Age'] = guess_ages[i,j]

        dataset['Age'] = dataset['Age'].astype(int)

    for dataset in combine:
        dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1



    for dataset in combine:
        dataset['IsAlone'] = 0
        dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1

    combine = [train_df, test_df]

    freq_port = train_df.Embarked.dropna().mode()[0]

    for dataset in combine:
        dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)

    test_df['Fare'].fillna(test_df['Fare'].dropna().median(), inplace=True)
    
    train_df = pd.get_dummies(train_df)
    test_df  = pd.get_dummies(test_df)

    test_df.head(10)
    return (train_df, test_df)

# %%
train = 'train.csv'
test = 'test.csv'
titanic_train,titanic_test = titanic_preprocessing(train, test)

# %%
print(titanic_test.shape, titanic_train.shape)
# Out:
# (418, 13) (891, 13)

# %%
titanic_train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Title  FamilySize  \
# 0         0       3    0   22      1      0   7.2500      1           2
# 1         1       1    1   38      1      0  71.2833      3           2
# 2         1       3    1   26      0      0   7.9250      2           1
# 3         1       1    1   35      1      0  53.1000      3           2
# 4         0       3    0   35      0      0   8.0500      1           1
#
#    IsAlone  Embarked_C  Embarked_Q  Embarked_S
# 0        0           0           0           1
# 1        0           1           0           0
# 2        1           0           0           1
# 3        0           0           0           1
# 4        1           0           0           1

# %%
titanic_test.head()
# Out:
#    PassengerId  Pclass  Sex  Age  SibSp  Parch     Fare  Title  FamilySize  \
# 0          892       3    0   34      0      0   7.8292      1           1
# 1          893       3    1   47      1      0   7.0000      3           2
# 2          894       2    0   62      0      0   9.6875      1           1
# 3          895       3    0   27      0      0   8.6625      1           1
# 4          896       3    1   22      1      1  12.2875      3           3
#
#    IsAlone  Embarked_C  Embarked_Q  Embarked_S
# 0        1           0           1           0
# 1        0           0           0           1
# 2        1           0           1           0
# 3        1           0           0           1
# 4        0           0           0           1

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=3)

# %%
Y_train = titanic_train['Survived']

# %%
Y_train.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
X_train = titanic_train.iloc[:,1:]

# %%
X_train.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Title', 'FamilySize',
#        'IsAlone', 'Embarked_C', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
X_train.shape
# Out:
# (891, 12)

# %%
clf = clf.fit(X_train,Y_train)

# %%
#plot_decision_tree(clf,X_train.columns,df1.columns[1])
# 绘制决策树
plt.figure(figsize=(12, 8))
tree.plot_tree(clf)
plt.show()

# %%
from sklearn.metrics import accuracy_score
Y_pred = clf.predict(titanic_test.iloc[:,1:])
df1 = pd.DataFrame(np.array([titanic_test.iloc[:,0],Y_pred]).T,columns=['PassengerId','Survived'])

# %%
df1.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df1.to_csv('prediction.csv',index=False)

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived'], dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %% [markdown]
# def plot_decision_tree(clf,feature_name,target_name):
#     from IPython.display import Image
#     from io import StringIO
#     import pydotplus
#     dot_data = StringIO()
#     tree.export_graphviz(clf, out_file=np.array(dot_data),
#                          feature_names=feature_name,
#                          class_names=target_name,
#                          filled=True, rounded=True,
#                          special_characters=True)
#     graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#     return Image(graph.create_png())

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer,accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
Y = titanic_train['Survived']
X = titanic_train.iloc[:,1:]

# %%
def grid_search_output(parameters,X,Y,clf):
    num_test = 0.20
    X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = num_test,random_state = 23)
    acc_scorer = make_scorer(accuracy_score)
    grid_obj = GridSearchCV(clf, parameters, scoring=acc_scorer)
    grid_obj = grid_obj.fit(X_train, Y_train)    
    return grid_obj.cv_results_

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
def plot_my_data(X,Ytest,Ytrain):
    
    plt.plot(X,Ytest,'r-',X,Ytrain)
    plt.xlabel(X)
    plt.xticks(X)
    plt.ylabel('Mean Scores')
    plt.show()
    return plt

# %%
parameters1 = {'n_estimators': [2,4,6,8,16,32]}
parameters2 = {'max_features': ['log2', 'sqrt','auto']}
parameters3 = {'criterion': ['entropy', 'gini']}
parameters4 = {'max_depth': [2, 3, 5, 10]}
parameters5 = {'min_samples_split': [2, 3, 5]}
parameters6 = {'min_samples_leaf': [1,5,8]}

# %%
clf = RandomForestClassifier(oob_score=True)
t1 = grid_search_output(parameters1,X,Y,clf)
# Out:
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(

# %%
t1['mean_test_score'].tolist()
# Out:
# [0.779424800551561,
#  0.7907416527134836,
#  0.7963459076135132,
#  0.8005318625036935,
#  0.7963557569191372,
#  0.7991825076332117]

# %%
t2
# Out:
# {'mean_fit_time': array([0.27855973, 0.27346854, 0.3001389 ]),
#  'std_fit_time': array([0.00807436, 0.00714605, 0.02097869]),
#  'mean_score_time': array([0.01822581, 0.01744123, 0.01926079]),
#  'std_score_time': array([0.00074327, 0.00151454, 0.00291612]),
#  'param_max_features': masked_array(data=['log2', 'sqrt', 'auto'],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'log2'},
#   {'max_features': 'sqrt'},
#   {'max_features': 'auto'}],
#  'split0_test_score': array([0.81118881, 0.81118881, 0.8041958 ]),
#  'split1_test_score': array([0.79020979, 0.78321678, 0.79020979]),
#  'split2_test_score': array([0.83098592, 0.80985915, 0.82394366]),
#  'split3_test_score': array([0.78873239, 0.77464789, 0.76760563]),
#  'split4_test_score': array([0.80985915, 0.80985915, 0.81690141]),
#  'mean_test_score': array([0.80619521, 0.79775436, 0.80057126]),
#  'std_test_score': array([0.01557834, 0.01561273, 0.02010061]),
#  'rank_test_score': array([1, 3, 2])}

# %%
plot_my_data(parameters1[],t1['mean_test_score'],t1['mean_train_score'])
# plot_my_data(parameters1['n_estimators'],t1['mean_test_score'].tolist(),t1['std_test_score'].tolist())
# Out:
#   Cell In[97], line 1
#     plot_my_data(parameters1[],t1['mean_test_score'],t1['mean_train_score'])
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
t2 = grid_search_output(parameters2,X,Y,clf)
plot_my_data(parameters2,t2['mean_test_score'].tolist(),t2['std_test_score'].tolist())
# Out:
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 2
#       1 t2 = grid_search_output(parameters2,X,Y,clf)
# ----> 2 plot_my_data(parameters2,t2['mean_test_score'].tolist(),t2['std_test_score'].tolist())
#
# Cell In[75], line 6, in plot_my_data(X, Ytest, Ytrain)
#       4 def plot_my_data(X,Ytest,Ytrain):
# ----> 6     plt.plot(X,Ytest,'r-',X,Ytrain)
#       7     plt.xlabel(X)
#       8     plt.xticks(X)
#
# File C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\matplotlib\pyplot.py:2740, in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\matplotlib\axes\_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     x, y = index_of(xy[-1])
#     498 if self.axes.xaxis is not None:
# --> 499     self.axes.xaxis.update_units(x)
#     500 if self.axes.yaxis is not None:
#     501     self.axes.yaxis.update_units(y)
#
# File C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\matplotlib\axis.py:1608, in Axis.update_units(self, data)
#    1606 neednew = self.converter != converter
#    1607 self.converter = converter
# -> 1608 default = self.converter.default_units(data, self)
#    1609 if default is not None and self.units is None:
#    1610     self.set_units(default)
#
# File C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\matplotlib\category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\matplotlib\category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File C:\Winpython\WPy64-31110\python-3.11.1.amd64\Lib\site-packages\matplotlib\category.py:225, in UnitData.update(self, data)
#     223 # check if convertible to number:
#     224 convertible = True
# --> 225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
#     227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#
# TypeError: unhashable type: 'dict'

# %%
t3 = grid_search_output(parameters3,X,Y,clf)
plot_my_data(parameters3,t3['mean_test_score'],t3['mean_train_score'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 2
#       1 t3 = grid_search_output(parameters3,X,Y,clf)
# ----> 2 plot_my_data(parameters3,t3['mean_test_score'],t3['mean_train_score'])
#
# KeyError: 'mean_train_score'

# %%
t4 = grid_search_output(parameters4,X,Y,clf)
plot_my_data(parameters4,t4['mean_test_score'],t4['mean_train_score'])

# %%
t5 = grid_search_output(parameters5,X,Y,clf)
plot_my_data(parameters5,t5['mean_test_score'],t5['mean_train_score'])

# %%
t6 = grid_search_output(parameters6,X,Y,clf)
plot_my_data(parameters6,t6['mean_test_score'],t6['mean_train_score'])

# %%
clf1 = RandomForestClassifier(n_estimators=15,criterion='gini',min_samples_leaf=5, max_depth=5,max_features='sqrt')

# %%
clf1 = clf1.fit(X_train,Y_train)
Y_pred_random_forest = clf1.predict(titanic_test.iloc[:,1:])
df_random = DataFrame(np.array([titanic_test.iloc[:,0],Y_pred_random_forest]).T,columns=['PassengerId','Survived'])
df_random.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df_random.to_csv('prediction_random_forest.csv',index=False)

# %%
# 设置随机森林回归模型的参数
param_grid = {
    'n_estimators': [10, 50, 100, 200, 400],
    'max_depth': [None, 10, 20, 30, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['log2', 'sqrt']}

# %%
X_train.head()
# Out:
#    Pclass  Sex  Age  SibSp  Parch     Fare  Title  FamilySize  IsAlone  \
# 0       3    0   22      1      0   7.2500      1           2        0
# 1       1    1   38      1      0  71.2833      3           2        0
# 2       3    1   26      0      0   7.9250      2           1        1
# 3       1    1   35      1      0  53.1000      3           2        0
# 4       3    0   35      0      0   8.0500      1           1        1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0       False       False        True
# 1        True       False       False
# 2       False       False        True
# 3       False       False        True
# 4       False       False        True

# %%
X_train.shape
# Out:
# (891, 12)

# %%
Y.values.shape
# Out:
# (891,)

# %%
# !pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.3.0)
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/79/3d/02d5d3ed359498fec3abdf65407d3c07e3b8765af17464969055aaec5171/scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Downloading scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.6 MB 1.7 MB/s eta 0:00:07
#    ---------------------------------------- 0.1/10.6 MB 919.0 kB/s eta 0:00:12
#    ---------------------------------------- 0.1/10.6 MB 751.6 kB/s eta 0:00:14
#    ---------------------------------------- 0.1/10.6 MB 751.6 kB/s eta 0:00:14
#     --------------------------------------- 0.1/10.6 MB 655.8 kB/s eta 0:00:16
#     --------------------------------------- 0.2/10.6 MB 888.8 kB/s eta 0:00:12
#    - -------------------------------------- 0.3/10.6 MB 967.8 kB/s eta 0:00:11
#    - -------------------------------------- 0.4/10.6 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/10.6 MB 1.1 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/10.6 MB 1.2 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/10.6 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.7/10.6 MB 1.2 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/10.6 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.9/10.6 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/10.6 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.1/10.6 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.2/10.6 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/10.6 MB 1.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.4/10.6 MB 1.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.5/10.6 MB 1.6 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/10.6 MB 1.7 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/10.6 MB 1.8 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/10.6 MB 1.8 MB/s eta 0:00:05
#    ------- -------------------------------- 1.9/10.6 MB 1.7 MB/s eta 0:00:06
#    ------- -------------------------------- 2.0/10.6 MB 1.8 MB/s eta 0:00:05
#    -------- ------------------------------- 2.2/10.6 MB 1.8 MB/s eta 0:00:05
#    -------- ------------------------------- 2.2/10.6 MB 1.8 MB/s eta 0:00:05
#    --------- ------------------------------ 2.5/10.6 MB 1.9 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/10.6 MB 1.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.8/10.6 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.8/10.6 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/10.6 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/10.6 MB 2.0 MB/s eta 0:00:04
#    ------------- -------------------------- 3.6/10.6 MB 2.3 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/10.6 MB 2.3 MB/s eta 0:00:04
#    -------------- ------------------------- 3.8/10.6 MB 2.3 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.6 MB 2.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.3/10.6 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/10.6 MB 2.6 MB/s eta 0:00:03
#    ------------------ --------------------- 4.9/10.6 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 5.1/10.6 MB 2.6 MB/s eta 0:00:03
#    ------------------- -------------------- 5.2/10.6 MB 2.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.5/10.6 MB 2.8 MB/s eta 0:00:02
#    ------------------------ --------------- 6.4/10.6 MB 3.2 MB/s eta 0:00:02
#    ------------------------- -------------- 6.7/10.6 MB 3.2 MB/s eta 0:00:02
#    -------------------------- ------------- 6.9/10.6 MB 3.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.7/10.6 MB 3.6 MB/s eta 0:00:01
#    ------------------------------- -------- 8.3/10.6 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 8.6/10.6 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.8/10.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.0/10.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.0/10.6 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.5/10.6 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.5/10.6 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.6 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 4.3 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.4.2

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
# 网格搜索法确定最佳参数
rf = RandomForestRegressor(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='neg_mean_squared_log_error', verbose=2, n_jobs=-1)
grid_search.fit(X_train, Y.values)
 
# 输出最佳参数
#print(grid_search.best_params_)

#https://blog.csdn.net/m0_61399808/article/details/132136754
# Out:
# Fitting 5 folds for each of 450 candidates, totalling 2250 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30, 50],
#                          'max_features': ['log2', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100, 200, 400]},
#              scoring='neg_mean_squared_log_error', verbose=2)

# %%
from matplotlib import pyplot as plt
# 可视化处理
results = pd.DataFrame(grid_search.cv_results_)
print(results)
mse = abs(results['mean_test_score'])
 
plt.figure(figsize=(10, 8))
plt.title("Random Forest Grid Search MSEs", fontsize=16)
plt.xlabel("Parameter Set", fontsize=16)
plt.ylabel("MSE Score", fontsize=16)
plt.plot(range(1, len(mse) + 1), mse, color='#d7191c', linestyle='--', label='MSE')
plt.grid(False)
plt.legend(loc='best', fontsize=14)
 
plt.show()
plt.clf()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.053473      0.008058         0.008723        0.000827
# 1         0.253191      0.011547         0.016795        0.001205
# 2         0.506098      0.017658         0.027984        0.000632
# 3         0.953843      0.019761         0.052370        0.003927
# 4         1.884507      0.036412         0.096945        0.003462
# ..             ...           ...              ...             ...
# 445       0.044677      0.000868         0.006996        0.000632
# 446       0.189092      0.001599         0.015191        0.000400
# 447       0.370588      0.008881         0.026585        0.001199
# 448       0.604418      0.037072         0.027585        0.001356
# 449       0.960299      0.046221         0.046006        0.002732
#
#     param_max_depth param_max_features param_min_samples_leaf  \
# 0              None               log2                      1
# 1              None               log2                      1
# 2              None               log2                      1
# 3              None               log2                      1
# 4              None               log2                      1
# ..              ...                ...                    ...
# 445              50               sqrt                      4
# 446              50               sqrt                      4
# 447              50               sqrt                      4
# 448              50               sqrt                      4
# 449              50               sqrt                      4
#
#     param_min_samples_split param_n_estimators  \
# 0                         2                 10
# 1                         2                 50
# 2                         2                100
# 3                         2                200
# 4                         2                400
# ..                      ...                ...
# 445                      10                 10
# 446                      10                 50
# 447                      10                100
# 448                      10                200
# 449                      10                400
#
#                                                 params  split0_test_score  \
# 0    {'max_depth': None, 'max_features': 'log2', 'm...          -0.083169
# 1    {'max_depth': None, 'max_features': 'log2', 'm...          -0.080696
# 2    {'max_depth': None, 'max_features': 'log2', 'm...          -0.079650
# 3    {'max_depth': None, 'max_features': 'log2', 'm...          -0.078783
# 4    {'max_depth': None, 'max_features': 'log2', 'm...          -0.078022
# ..                                                 ...                ...
# 445  {'max_depth': 50, 'max_features': 'sqrt', 'min...          -0.074088
# 446  {'max_depth': 50, 'max_features': 'sqrt', 'min...          -0.071676
# 447  {'max_depth': 50, 'max_features': 'sqrt', 'min...          -0.071614
# 448  {'max_depth': 50, 'max_features': 'sqrt', 'min...          -0.071062
# 449  {'max_depth': 50, 'max_features': 'sqrt', 'min...          -0.070981
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0            -0.080503          -0.065440          -0.080334
# 1            -0.081157          -0.060974          -0.075974
# 2            -0.079392          -0.060152          -0.076567
# 3            -0.079203          -0.059289          -0.076317
# 4            -0.078555          -0.058751          -0.076138
# ..                 ...                ...                ...
# 445          -0.069647          -0.062356          -0.062920
# 446          -0.069525          -0.060362          -0.064061
# 447          -0.069637          -0.059435          -0.064186
# 448          -0.070001          -0.059074          -0.064039
# 449          -0.070087          -0.059120          -0.064076
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            -0.062591        -0.074407        0.008592              445
# 1            -0.060736        -0.071907        0.009205              437
# 2            -0.062851        -0.071722        0.008458              429
# 3            -0.063710        -0.071460        0.008311              421
# 4            -0.064911        -0.071275        0.007994              413
# ..                 ...              ...             ...              ...
# 445          -0.053714        -0.064545        0.006955              235
# 446          -0.051371        -0.063399        0.007216               51
# 447          -0.051697        -0.063314        0.007206               27
# 448          -0.052145        -0.063264        0.007042               15
# 449          -0.052593        -0.063371        0.006896               39
#
# [450 rows x 18 columns]
